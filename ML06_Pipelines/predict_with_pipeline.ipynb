# %%
import pickle
import numpy as np
from sklearn import set_config
set_config(transform_output="pandas")

# %%
pipe = pickle.load(open('models/pipe.pkl', 'rb'))

# %%
test_input2 = np.array([1, 'female', 30.0, 1, 0, 17.6, 'C'], dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# /home/varsha/PracticePython/pracvenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/varsha/PracticePython/pracvenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])

# %%
test_input3 = np.array([3,	'male',	22.0,	1,	0	, 7.2500	, 'S'], dtype=object).reshape(1,7)

# %%
print(pipe.predict(test_input3))
# Out:
# [0]
# /home/varsha/PracticePython/pracvenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/varsha/PracticePython/pracvenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
