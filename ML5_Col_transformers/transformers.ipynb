# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("covid_data.csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %% [markdown]
# <h3> Column transformer traditionally </h3>
# <p> here columns are to be tranformed separately and then the data is merged to get all columns </p>

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
X_train, X_test, y_train, y_test = train_test_split(df.drop('has_covid', axis=1),df['has_covid'], test_size=0.2, random_state=0)

# %% [markdown]
# <p> using SimpleImputer it will fill up the spaces where the data has blank value in means, here age col is not categorical so we'll impute with average values</p>

# %%
si = SimpleImputer()
X_train_fever = si.fit_transform(X_train[['fever']])
X_train_fever.shape
# Out:
# (80, 1)

# %%
X_test_fever = si.fit_transform(X_test[['fever']])

# %%
df['city'].unique()
# Out:
# array(['Kolkata', 'Delhi', 'Mumbai', 'Bangalore'], dtype=object)

# %%
df['cough'].unique()
# Out:
# array(['Mild', 'Strong'], dtype=object)

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# here we have ordinal categories are: cough and label encoding = covid applied on output col
# and nominal data : City, Gender

# %% [markdown]
# <p> One Hot Encoding on City and Gender Col <p>

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
ohe = OneHotEncoder(drop='first')
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])

# also the test data
X_test_gender_city = ohe.fit_transform(X_test[['gender','city']])

X_train_gender_city.shape
# Out:
# (80, 4)

# %%
# Extracting Age
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values

X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values

X_train_age.shape
# Out:
# (80, 1)

# %%
oe = OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough = oe.fit_transform(X_train[['cough']])

# also the test data
X_test_cough = oe.fit_transform(X_test[['cough']])

X_train_cough.shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 5
#       2 X_train_cough = oe.fit_transform(X_train[['cough']])
#       4 # also the test data
# ----> 5 X_test_cough = oe.fit_transform((X_test[['cough']]))
#       7 X_train_cough.shape
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X_train_transformed = np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
# also the test data
X_test_transformed = np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)

X_train_transformed.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 X_train_transformed = np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
#       2 # also the test data
#       3 X_test_transformed = np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)
#
# NameError: name 'X_train_cough' is not defined
