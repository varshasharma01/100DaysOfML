# %%
import numpy as np
import pandas as pd

# %%
# categorical data is to be converted in numerical data in order to work with machine learning and models

# %%
df = pd.read_csv("cars.csv")

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df['brand'].unique()
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Fiat', 'Datsun', 'Jeep',
#        'Mercedes-Benz', 'Mitsubishi', 'Audi', 'Volkswagen', 'BMW',
#        'Nissan', 'Lexus', 'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo',
#        'Kia', 'Force', 'Ambassador', 'Ashok', 'Isuzu', 'Opel', 'Peugeot'],
#       dtype=object)

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Land                6
# Force               6
# Isuzu               5
# Ambassador          4
# Kia                 4
# MG                  3
# Daewoo              3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %% [markdown]
# <h1> OneHotEncoding Using Pandas </h1>

# %%
# get_dummies is a function that is used to divide n categories into n cols

pd.get_dummies(df, columns=['fuel','owner'])
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# <h1> K-1 One Hot Encoding </h1>

# %%
pd.get_dummies(df, columns=['fuel','owner'], drop_first= True,dtype=int)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000            1         0            0
# 1       Skoda     120000         370000            1         0            0
# 2       Honda     140000         158000            0         0            1
# 3     Hyundai     127000         225000            1         0            0
# 4      Maruti     120000         130000            0         0            1
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000            0         0            1
# 8124  Hyundai     119000         135000            1         0            0
# 8125   Maruti     120000         382000            1         0            0
# 8126     Tata      25000         290000            1         0            0
# 8127     Tata      25000         290000            1         0            0
#
# ...

# %% [markdown]
# <h1>Using OneHotEncoder Class </h1>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:4], df.iloc[:,-1], test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
#          brand  km_driven    fuel         owner
# 3042   Hyundai      60000     LPG   First Owner
# 1520      Tata     150000  Diesel   Third Owner
# 2611   Hyundai     110000  Diesel  Second Owner
# 3544  Mahindra      28000  Diesel  Second Owner
# 4138    Maruti      15000  Petrol   First Owner

# %%
ohe = OneHotEncoder(drop= 'first', sparse=False, dtype=np.int32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ohe = OneHotEncoder(drop= 'first', sparse=False, dtype=np.int32)
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
ohe
# Out:
# OneHotEncoder()

# %%
X_train_new = ohe.fit_transform(X_train[['fuel', 'owner']])

# %%
X_test_new = ohe.fit_transform(X_test[['fuel', 'owner']])

# %%
X_train.shape
# Out:
# (6502, 4)

# %%
X_train_new.shape
# Out:
# (6502, 9)

# %%
np.hstack((X_train[['brand','km_driven']].values, X_train_new.toarray()))
# Out:
# array([['Hyundai', 60000, 0.0, ..., 0.0, 0.0, 0.0],
#        ['Tata', 150000, 0.0, ..., 0.0, 0.0, 1.0],
#        ['Hyundai', 110000, 0.0, ..., 1.0, 0.0, 0.0],
#        ...,
#        ['Hyundai', 90000, 0.0, ..., 1.0, 0.0, 0.0],
#        ['Volkswagen', 90000, 0.0, ..., 0.0, 0.0, 0.0],
#        ['Hyundai', 110000, 0.0, ..., 0.0, 0.0, 0.0]],
#       shape=(6502, 11), dtype=object)

# %% [markdown]
# <h2>OneHotEncoding with top categories</h2>

# %%
count= df['brand'].value_counts()

# %%
df['brand'].nunique()
threshold = 100

# %%
repl = count[count<=threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl, 'uncommon'), dtype = int).sample(5)
# Out:
#       BMW  Chevrolet  Ford  Honda  Hyundai  Mahindra  Maruti  Renault  Skoda  \
# 6369    0          0     0      0        1         0       0        0      0
# 968     0          0     0      0        0         0       0        0      0
# 3337    0          0     0      0        0         0       1        0      0
# 901     0          0     0      0        0         0       1        0      0
# 6183    0          0     0      0        0         0       0        0      1
#
#       Tata  Toyota  Volkswagen  uncommon
# 6369     0       0           0         0
# 968      0       0           1         0
# 3337     0       0           0         0
# 901      0       0           0         0
# 6183     0       0           0         0
