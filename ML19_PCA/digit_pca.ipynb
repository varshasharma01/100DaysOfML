# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('digits.csv')

# %%
df.head(4)
# Out:
#    ImageId  Label
# 0        1      0
# 1        2      0
# 2        3      0
# 3        4      0
